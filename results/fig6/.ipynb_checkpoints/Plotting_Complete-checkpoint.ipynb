# %%
import numpy as np
import re
import glob
import matplotlib.pyplot as plt
import matplotlib as mpl
mpl.rcParams['pdf.fonttype'] = 42

# --- CONFIG ---
num_chains = 25
bond_length_interval = 0.1
lengths = [bond_length_interval * point for point in range(3, num_chains + 1)]

pattern_steps = re.compile(r'CASSCF converged in\s+(\d+)\s+macro\s+\(\s*(\d+)\s+JK\s+(\d+)\s+micro')
pattern_energy = re.compile(r'CASSCF energy\s*=\s*([-+]?\d*\.\d+(?:[eE][-+]?\d+)?)')

# ============================================
# =========== READ HF DIRECTORY ==============
# ============================================
log_files_hf = sorted(glob.glob("cas_init_result/log_*.txt"),
                      key=lambda x: int(re.search(r'\d+', x).group()))

nn_macro, nn_jk, nn_micro = [], [], []
hf_macro, hf_jk, hf_micro = [], [], []
nn_energy, hf_energy = [], []

for log_file in log_files_hf:
    with open(log_file, "r") as f:
        lines = f.readlines()

    # Steps
    matches_steps = [pattern_steps.search(l) for l in lines if "CASSCF converged" in l]
    matches_steps = [m for m in matches_steps if m]

    # Energies
    matches_energy = [pattern_energy.search(l) for l in lines if "CASSCF energy" in l]
    matches_energy = [m for m in matches_energy if m]

    if len(matches_steps) >= 2 and len(matches_energy) >= 2:
        nn_s = tuple(map(int, matches_steps[0].groups()))
        hf_s = tuple(map(int, matches_steps[1].groups()))

        nn_macro.append(nn_s[0])
        nn_jk.append(nn_s[1])
        nn_micro.append(nn_s[2])

        hf_macro.append(hf_s[0])
        hf_jk.append(hf_s[1])
        hf_micro.append(hf_s[2])

        nn_energy.append(float(matches_energy[0].group(1)))
        hf_energy.append(float(matches_energy[1].group(1)))


# ============================================
# ========== READ AVAS DIRECTORY =============
# ============================================
log_files_avas = sorted(glob.glob("cas_init_result_avas/log_*.txt"),
                        key=lambda x: int(re.search(r'\d+', x).group()))

avas_macro, avas_jk, avas_micro = [], [], []
avas_energy = []

for log_file in log_files_avas:
    with open(log_file, "r") as f:
        lines = f.readlines()

    # Steps
    matches_steps = [pattern_steps.search(l) for l in lines if "CASSCF converged" in l]
    matches_steps = [m for m in matches_steps if m]

    # Energies
    matches_energy = [pattern_energy.search(l) for l in lines if "CASSCF energy" in l]
    matches_energy = [m for m in matches_energy if m]

    if len(matches_steps) >= 2 and len(matches_energy) >= 2:
        nn_s = tuple(map(int, matches_steps[0].groups()))
        av_s = tuple(map(int, matches_steps[1].groups()))

        # NN values (should match HF directory’s NN)
        # we skip storing NN here to avoid duplication

        avas_macro.append(av_s[0])
        avas_jk.append(av_s[1])
        avas_micro.append(av_s[2])

        avas_energy.append(float(matches_energy[1].group(1)))


# ============================================
# ================= PLOTTING =================
# ============================================

fig_titles = ['Macro Iterations', 'JK Steps', 'Micro Iterations']
ylabels = ['Macro Steps', 'JK Steps', 'Micro Steps']
ylims = [12, 120, 25]

nn_all    = [nn_macro, nn_jk, nn_micro]
hf_all    = [hf_macro, hf_jk, hf_micro]
avas_all  = [avas_macro, avas_jk, avas_micro]

for i in range(3):
    plt.figure(figsize=(8,5))

    plt.plot(lengths[:-2], nn_all[i][:-2],
             label='BasisNN', marker='o', markerfacecolor=(48/255, 72/255, 156/255),
             color=(48/255, 72/255, 156/255))

    plt.plot(lengths[:-2], hf_all[i][:-2],
             label='HF', marker='o', markerfacecolor=(153/255, 0/255, 0/255),
             color=(153/255, 0/255, 0/255))

    plt.plot(lengths[:-2], avas_all[i][:-2],
             label='AVAS', marker='o', markerfacecolor=(0/255, 105/255, 52/255),
             color=(0/255, 105/255, 52/255))

    plt.xlabel('Bond Length (Å)')
    plt.ylabel(ylabels[i])
    plt.title(f'CASSCF {fig_titles[i]} Comparison')
    plt.tick_params(axis='both', direction='in',
                    length=6, width=1, labelsize=14, top=True, right=True)
    plt.xlim(0, 2.5)
    plt.ylim(0, ylims[i])
    plt.legend()
    plt.tight_layout()
    plt.savefig(f'figs/fig6_{i}.pdf', metadata={"TextAsShapes": False})


# ================= ENERGY DIFFERENCE =================

energy_diff_hf   = (np.array(nn_energy) - np.array(hf_energy)) * 1e3
energy_diff_avas = (np.array(nn_energy) - np.array(avas_energy)) * 1e3

plt.figure(figsize=(8,5))
plt.plot(lengths[:-2], energy_diff_hf[:-2],
         label='ΔE (NN - HF)', marker='o', markerfacecolor='white',
         color=(153/255, 0/255, 0/255))
plt.plot(lengths[:-2], energy_diff_avas[:-2],
         label='ΔE (NN - AVAS)', marker='o', markerfacecolor='white',
         color=(0/255,105/255,52/255))

plt.axhline(0, linestyle='--', linewidth=1, color='gray')
plt.xlabel('Bond Length (Å)')
plt.ylabel('Energy Difference ($10^{-3}$ Ha)')
plt.title('CASSCF Energy Difference Comparison')
plt.tick_params(axis='both', direction='in', length=6, width=1,
                labelsize=14, top=True, right=True)
plt.xlim(0, 2.5)
plt.ylim(-3, 0.5)
plt.legend()
plt.tight_layout()

plt.show()
# Out:
# /tmp/ipykernel_125727/3621162577.py:125: UserWarning: Unknown infodict keyword: 'TextAsShapes'. Must be one of {'Author', 'ModDate', 'Trapped', 'Creator', 'CreationDate', 'Title', 'Producer', 'Subject', 'Keywords'}.
#   plt.savefig(f'figs/fig6_{i}.pdf', metadata={"TextAsShapes": False})

# %%
import re
import matplotlib.pyplot as plt

# --- Load log files ---
log_file_hf = "cas_init_result/log_4.txt"
log_file_avas = "cas_init_result_avas/log_4.txt"

# --- Parse NN and HF from HF log ---
with open(log_file_hf, "r") as f:
    lines_hf = f.readlines()

casci_lines_hf = [line for line in lines_hf if "CASCI E" in line]
basisNN_E0_hf = float(re.search(r"CASCI E =\s*(-?\d+\.\d+)", casci_lines_hf[0]).group(1))
hf_E0 = float(re.search(r"CASCI E =\s*(-?\d+\.\d+)", casci_lines_hf[2]).group(1))

macro_pattern = re.compile(r"CASSCF E =\s*(-?\d+\.\d+)")
macro_lines_hf = [line for line in lines_hf if "macro iter" in line]
basisNN_lines_hf = macro_lines_hf[:2]
hf_lines = macro_lines_hf[2:]

basisNN_E_hf = [basisNN_E0_hf] + [float(macro_pattern.search(line).group(1)) for line in basisNN_lines_hf]
hf_E = [hf_E0] + [float(macro_pattern.search(line).group(1)) for line in hf_lines]

# --- Parse NN and AVAS from AVAS log ---
with open(log_file_avas, "r") as f:
    lines_avas = f.readlines()

casci_lines_avas = [line for line in lines_avas if "CASCI E" in line]
basisNN_E0_avas = float(re.search(r"CASCI E =\s*(-?\d+\.\d+)", casci_lines_avas[0]).group(1))
avas_E0 = float(re.search(r"CASCI E =\s*(-?\d+\.\d+)", casci_lines_avas[2]).group(1))

macro_lines_avas = [line for line in lines_avas if "macro iter" in line]
basisNN_lines_avas = macro_lines_avas[:2]
avas_lines = macro_lines_avas[2:]

basisNN_E_avas = [basisNN_E0_avas] + [float(macro_pattern.search(line).group(1)) for line in basisNN_lines_avas]
avas_E = [avas_E0] + [float(macro_pattern.search(line).group(1)) for line in avas_lines]

# --- Plot all three ---
plt.figure(figsize=(6, 4))
plt.plot(range(len(basisNN_E_hf)), basisNN_E_hf, label="BasisNN init", marker='o', markerfacecolor='white', color=(51/255,46/255,230/255))
plt.plot(range(len(hf_E)), hf_E, label="HF init", marker='o', markerfacecolor='white', color=(153/255,0/255,0/255))
plt.plot(range(len(avas_E)), avas_E, label="AVAS init", marker='o', markerfacecolor='white', color=(0/255,153/255,0/255))

plt.xlabel("Macro Iteration")
plt.ylabel("CASSCF Energy (Ha)")
plt.title("CASSCF Energy Convergence (log_4.txt)")
plt.legend()
plt.tick_params(axis='both', direction='in', length=6, width=1, labelsize=14, top=True, right=True)
plt.xlim(0, 6)
plt.ylim(-2.16, -2.12)
plt.tight_layout()
plt.show()
plt.savefig('figs/fig6_more.pdf', metadata={"TextAsShapes": False})
# Out:
# /tmp/ipykernel_125727/993507838.py:54: UserWarning: Unknown infodict keyword: 'TextAsShapes'. Must be one of {'Author', 'ModDate', 'Trapped', 'Creator', 'CreationDate', 'Title', 'Producer', 'Subject', 'Keywords'}.
#   plt.savefig('figs/fig6_more.pdf', metadata={"TextAsShapes": False})
